# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaykumar2409/Mnist_practice/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
(train_image,train_label),(test_image,test_label) =mnist.load_data()
model = Sequential()
model.add(Dense(512,activation='relu',input_shape=(28 * 28,)))
model.add(Dense(10,activation='softmax'))
digit = train_image[4:40] 
import matplotlib.pyplot as plt
print(digit.shape)
for i in digit:
   plt.imshow(i, cmap=plt.cm.binary) 
   plt.show()
# Out:
# (36, 28, 28)
